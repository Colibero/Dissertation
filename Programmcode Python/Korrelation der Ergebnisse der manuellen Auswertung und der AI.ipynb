# %%
##correlation of AI and manual validated counts on small images

import pandas as pd
import numpy as np
import os

#definition of marker
marker = 'HO-1'

path_AI = 'c:/Users/chris/OneDrive/AI/Validation/correlation_with_manual/'

if marker == 'HO-1':
    list_image= os.listdir('d:/D_lw/APromotion/Bilder/ho1 main/img_raw/')
    list_cells= os.listdir('d:/D_lw/APromotion/Bilder/ho1 main/img_pos_all/')
    file = '230727_ho1_raw.csv'
    deli = ';'

elif marker == 'IBA1':
    list_image= os.listdir('d:/D_lw/APromotion/Bilder/iba1 main/raw_update/')
    list_cells= os.listdir('d:/D_lw/APromotion/Bilder/iba1 main/img_pos_musk/')
    file = '230727_AIClassify_iba1_raw_incomplete.csv'
    deli = ', '

elif marker == 'CD206':
    list_image= os.listdir('d:/D_lw/APromotion/Bilder/cd206 main/raw_clean without 40-7 pgl muko/')
    list_cells= os.listdir('d:/D_lw/APromotion/Bilder/cd206 main/img_pos_musk/')
    file ="230525_AIClassify_cd206_raw.csv"
    deli = ','

file_path =path_AI + file
print(file_path)
print(list_cells)

list2=[]


        
list_image = [x[:29].lower() for x in list_image]
list_cells = [x[:29].lower() for x in list_cells]

df = pd.DataFrame(list_image ,columns= ['image'])

df['short_image'] = df['image'].str[:8]


df['portion'] = df['short_image'].str[5:7]
df['animal'] = df['short_image'].str[:2]
df['slide'] = df['short_image'].str[3]
df['layer'] = df['image'].apply(lambda x: 'musk' if 'musk' in x else 'muco')
df['genotype'] = df['animal'].apply(lambda x: 'WT' if int(x) in [36,38,41,43,45] else 'TG')
df['cell_count'] = df['image'].apply(lambda x: list_cells.count(x))


df_musk = df.loc[df['layer']=='musk', ['image','short_image','genotype','animal', 'portion', 'cell_count']]


import matplotlib.pyplot as plt

##correlation of ML and manual


# Read the CSV file into a pandas DataFrame
df_AI = pd.read_csv(file_path, delimiter = deli)
df_AI.columns = ['image_long', 'cell_count_AI']
df_AI['image'] = df_AI['image_long'].apply(lambda x: x[:29].lower())

df_correl_AI = df_musk.merge(df_AI, on = 'image')

#calculate Correlation of AI and manual count
correlation_coefficient = df_correl_AI['cell_count'].corr(df_correl_AI['cell_count_AI'])

print("Pearson correlation coefficient:", correlation_coefficient)

plt.scatter(df_correl_AI['cell_count'], df_correl_AI['cell_count_AI'])
plt.xlim(0, 40)
plt.ylim(0,40)
plt.xlabel('Manuelle Auswertung \n[Zellen pro mpf]', fontsize = 12)
plt.ylabel('Auswertung mit AI \n[Zellen pro mpf]', fontsize = 12)
plt.title(marker+': Korrelation von manueller Auswertung und AI ' , fontsize = 14)

plt.text(33, 3, 'ρ = {:.2f}'.format(correlation_coefficient), fontsize=12)
plt.show()


df_correl_AI.describe()
# Out:
# c:/Users/chris/OneDrive/AI/Validation/correlation_with_manual/230727_ho1_raw.csv
# ['36-4 Py HO-1 Muco_1498_RGB Trans10 (copy).tif', '36-4 Py HO-1 Muco_1498_RGB Trans100.tif', '36-4 Py HO-1 Muco_1498_RGB Trans102.tif', '36-4 Py HO-1 Muco_1498_RGB Trans103.tif', '36-4 Py HO-1 Muco_1498_RGB Trans110.tif', '36-4 Py HO-1 Muco_1498_RGB Trans112.tif', '36-4 Py HO-1 Muco_1498_RGB Trans116.tif', '36-4 Py HO-1 Muco_1498_RGB Trans12.tif', '36-4 Py HO-1 Muco_1498_RGB Trans120.tif', '36-4 Py HO-1 Muco_1498_RGB Trans121.tif', '36-4 Py HO-1 Muco_1498_RGB Trans128.tif', '36-4 Py HO-1 Muco_1498_RGB Trans131.tif', '36-4 Py HO-1 Muco_1498_RGB Trans16.tif', '36-4 Py HO-1 Muco_1498_RGB Trans17.tif', '36-4 Py HO-1 Muco_1498_RGB Trans18.tif', '36-4 Py HO-1 Muco_1498_RGB Trans19.tif', '36-4 Py HO-1 Muco_1498_RGB Trans20.tif', '36-4 Py HO-1 Muco_1498_RGB Trans24.tif', '36-4 Py HO-1 Muco_1498_RGB Trans25.tif', '36-4 Py HO-1 Muco_1498_RGB Trans26.tif', '36-4 Py HO-1 Muco_1498_RGB Trans27.tif', '36-4 Py HO-1 Muco_1498_RGB Trans28.tif', '36-4 Py HO-1 Muco_1498_RGB Trans30.tif', '36-4 Py HO-1 Muco_1498_RGB Trans31 (copy).tif', '36-4 Py HO-1 Muco_1498_RGB Trans34.tif', '36-4 Py HO-1 Muco_1498_RGB Trans36.tif', '36-4 Py HO-1 Muco_1498_RGB Trans39 (copy).tif', '36-4 Py HO-1 Muco_1498_RGB Trans4 (copy).tif', '36-4 Py HO-1 Muco_1498_RGB Trans40 (copy).tif', '36-4 Py HO-1 Muco_1498_RGB Trans42.tif', '36-4 Py HO-1 Muco_1498_RGB Trans43.tif', '36-4 Py HO-1 Muco_1498_RGB Trans47.tif', '36-4 Py HO-1 Muco_1498_RGB Trans49.tif', '36-4 Py HO-1 Muco_1498_RGB Trans50 (copy).tif', '36-4 Py HO-1 Muco_1498_RGB Trans52.tif', '36-4 Py HO-1 Muco_1498_RGB Trans57.tif', '36-4 Py HO-1 Muco_1498_RGB Trans64.tif', '36-4 Py HO-1 Muco_1498_RGB Trans65.tif', '36-4 Py HO-1 Muco_1498_RGB Trans66.tif', '36-4 Py HO-1 Muco_1498_RGB Trans67.tif', '36-4 Py HO-1 Muco_1498_RGB Trans69.tif', '36-4 Py HO-1 Muco_1498_RGB Trans7.tif', '36-4 Py HO-1 Muco_1498_RGB Trans70.tif', '36-4 Py HO-1 Muco_1498_RGB Trans74.tif', '36-4 Py HO-1 Muco_1498_RGB Trans76.tif', '36-4 Py HO-1 Muco_1498_RGB Trans81.tif', '36-4 Py HO-1 Muco_1498_RGB Trans83.tif', '36-4 Py HO-1 Muco_1498_RGB Trans84.tif', '36-4 Py HO-1 Muco_1498_RGB Trans9.tif', '36-4 Py HO-1 Muco_1498_RGB Trans90.tif', '36-4 Py HO-1 Muco_1498_RGB Trans92.tif', '36-4 Py HO-1 Muco_1499_RGB Trans12.tif', '36-4 Py HO-1 Muco_1499_RGB Trans13.tif', '36-4 Py HO-1 Muco_1499_RGB Trans15.tif', '36-4 Py HO-1 Muco_1499_RGB Trans24.tif', '36-4 Py HO-1 Muco_1499_RGB Trans26 (copy).tif', '36-4 Py HO-1 Muco_1499_RGB Trans27.tif', '36-4 Py HO-1 Muco_1499_RGB Trans28.tif', '36-4 Py HO-1 Muco_1499_RGB Trans40.tif', '36-4 Py HO-1 Muco_1499_RGB Trans46.tif', '36-4 Py HO-1 Muco_1499_RGB Trans6.tif', '36-4 Py HO-1 Muco_1499_RGB Trans7.tif', '36-4 Py HO-1 Muco_1499_RGB Trans8.tif', '36-4 Py HO-1 Muco_1500_RGB Trans109.tif', '36-4 Py HO-1 Muco_1500_RGB Trans117.tif', '36-4 Py HO-1 Muco_1500_RGB Trans122.tif', '36-4 Py HO-1 Muco_1500_RGB Trans133.tif', '36-4 Py HO-1 Muco_1500_RGB Trans138.tif', '36-4 Py HO-1 Muco_1500_RGB Trans150.tif', '36-4 Py HO-1 Muco_1500_RGB Trans152.tif', '36-4 Py HO-1 Muco_1500_RGB Trans162.tif', '36-4 Py HO-1 Muco_1500_RGB Trans171.tif', '36-4 Py HO-1 Muco_1500_RGB Trans178 (copy).tif', '36-4 Py HO-1 Muco_1500_RGB Trans179.tif', '36-4 Py HO-1 Muco_1500_RGB Trans184 (copy).tif', '36-4 Py HO-1 Muco_1500_RGB Trans189 (copy).tif', '36-4 Py HO-1 Muco_1500_RGB Trans19.tif', '36-4 Py HO-1 Muco_1500_RGB Trans190.tif', '36-4 Py HO-1 Muco_1500_RGB Trans192.tif', '36-4 Py HO-1 Muco_1500_RGB Trans199.tif', '36-4 Py HO-1 Muco_1500_RGB Trans203.tif', '36-4 Py HO-1 Muco_1500_RGB Trans209 (copy).tif', '36-4 Py HO-1 Muco_1500_RGB Trans213.tif', '36-4 Py HO-1 Muco_1500_RGB Trans220.tif', '36-4 Py HO-1 Muco_1500_RGB Trans221.tif', '36-4 Py HO-1 Muco_1500_RGB Trans228.tif', '36-4 Py HO-1 Muco_1500_RGB Trans230.tif', '36-4 Py HO-1 Muco_1500_RGB Trans233.tif', '36-4 Py HO-1 Muco_1500_RGB Trans234.tif', '36-4 Py HO-1 Muco_1500_RGB Trans236.tif', '36-4 Py HO-1 Muco_1500_RGB Trans239.tif', '36-4 Py HO-1 Muco_1500_RGB Trans33.tif', '36-4 Py HO-1 Muco_1500_RGB ...
# Pearson correlation coefficient: 0.93575253395675
#         cell_count  cell_count_AI
# count  1034.000000    1034.000000
# mean      4.243714       3.589942
# std       5.526368       4.285564
# min       0.000000       0.000000
# 25%       1.000000       1.000000
# 50%       3.000000       2.000000
# 75%       6.000000       5.000000
# max      55.000000      46.000000

# %%
#correlation with final results of AI on Whole Slide Images and the manual counts


import csv

data = []

if marker == 'IBA1':
    file2 = '230414_fullslideiba1_scan_211109_resnet_corr.csv'
    stain = 'iba1'
elif marker == 'CD206':
    stain='cd206'
    file2 = '20230727_fullslidecd206_scan_211109_resnet18_cropped.csv'
elif marker == 'HO-1':
    stain = 'ho1'
    file2 = '230414_fullslideho1_scan_211109_resnet18_reverse.csv'
path2 = 'c:/Users/chris/OneDrive/AI/Validation/fullslide_scans/'


file_path =path2 +file2
print(file_path)

df_AI_fullslide = pd.read_csv(file_path, delimiter = ',' , usecols=[0,1,2])
df_AI_fullslide.describe()


df_AI_fullslide.columns =['slide', 'count', 'area']
pd.to_numeric(df_AI_fullslide['count'])
pd.to_numeric(df_AI_fullslide['area'])
df_AI_fullslide['count per area'] = df_AI_fullslide['area']/df_AI_fullslide['count']
df_AI_fullslide['ID'] = df_AI_fullslide['slide'].str[:-5]
df_AI_fullslide
# Out:
# c:/Users/chris/OneDrive/AI/Validation/fullslide_scans/230414_fullslideho1_scan_211109_resnet18_reverse.csv
#               slide       count  area  count per area          ID
# 0   3605ppvho1.mrxs   24.367121   177        7.263886  3605ppvho1
# 1   3606pglho1.mrxs  154.336583    68        0.440595  3606pglho1
# 2   3606ppvho1.mrxs   25.765203   395       15.330754  3606ppvho1
# 3   3607pglho1.mrxs   15.241063   212       13.909791  3607pglho1
# 4   3607pylho1.mrxs   15.293558    67        4.380929  3607pylho1
# 5   3701pylho1.mrxs   39.034971    77        1.972590  3701pylho1
# 6   3702pglho1.mrxs   12.029375   121       10.058711  3702pglho1
# 7   3702ppvho1.mrxs   11.668613   415       35.565495  3702ppvho1
# 8   3703ppvho1.mrxs   10.738253   143       13.316877  3703ppvho1
# 9   3704pylho1.mrxs  292.361002    96        0.328361  3704pylho1
# 10  3708pglho1.mrxs   19.813546   251       12.668101  3708pglho1
# 11  3802pglho1.mrxs   10.848651   159       14.656200  3802pglho1
# 12  3802ppvho1.mrxs    1.627764     7        4.300378  3802ppvho1
# 13  3803pglho1.mrxs   14.841531    90        6.064064  3803pglho1
# 14  3806pylho1.mrxs   11.480653    30        2.613092  3806pylho1
# 15  3807ppvho1.mrxs   24.221488   426       17.587689  3807ppvho1
# 16  3807pylho1.mrxs    9.041607   205       22.672961  3807pylho1
# 17  3902pglho1.mrxs   12.365803    71        5.741641  3902pglho1
# 18  3902pylho1.mrxs    6.161758    55        8.926024  3902pylho1
# 19  3903ppvho1.mrxs   25.173126    98        3.893041  3903ppvho1
# 20  3907pglho1.mrxs   13.277735    86        6.477008  3907pglho1
# 21  4002ppvho1.mrxs   18.718929    62        3.312155  4002ppvho1
# 22  4004ppvho1.mrxs   30.919281   713       23.060045  4004ppvho1
# 23  4004pylho1.mrxs   22.502627   146        6.488131  4004pylho1
# 24  4006pglho1.mrxs   20.320067   252       12.401534  4006pglho1
# 25  4007pglho1.mrxs   19.060183   174        9.128979  4007pglho1
# 26  4007pylho1.mrxs    3.258709    41       12.581671  4007pylho1
# 27  4102pglho1.mrxs   10.571536    88        8.324240  4102pglho1
# 28  4102ppvho1.mrxs    8.527759    14        1.641697  4102ppvho1
# 29  4102pylho1.mrxs   27.518042   217        7.885735  4102pylho1
# 30  4105pglho1.mrxs   18.921716   276       14.586415  4105pglho1
# 31  4107ppvho1.mrxs   24.324792   187        7.687630  4107ppvho1
# 32  4107pylho1.mrxs   23.327643   154        6.601610  4107pylho1
# 33  4202pglho1.mrxs   17.444504    86        4.929919  4202pglho1
# 34  4202ppvho1.mrxs   30.419899   510       16.765341  4202ppvho1
# 35  4202pylho1.mrxs   23.280660   162        6.958565  4202pylho1
# 36  4207pglho1.mrxs   18.457008    45        2.438098  4207pglho1
# 37  4207ppvho1.mrxs   14.870675   126        8.473052  4207ppvho1
# 38  4207pylho1.mrxs   23.774577    34        1.430099  4207pylho1
# 39  4302pglho1.mrxs   13.883763   221       15.917875  4302pglho1
# 40  4302ppvho1.mrxs   13.534996   195       14.407097  4302ppvho1
# 41  4302pylho1.mrxs   29.505218   137        4.643246  4302pylho1
# 42  4307pglho1.mrxs   23.634931   354       14.977831  4307pglho1
# 43  4307ppvho1.mrxs   36.425661   461       12.655913  4307ppvho1
# 44  4307pylho1.mrxs   11.544507   445       38.546470  4307pylho1
# 45  4402pglho1.mrxs   12.124497   174       14.351111  4402pglho1
# 46  4402ppvho1.mrxs    3.375752    29        8.590678  4402ppvho1
# 47  4404ppvho1.mrxs    6.012363    23        3.825451  4404ppvho1
# 48  4406pylho1.mrxs   16.977918    75        4.417503  4406pylho1
# 49  4408pylho1.mrxs    3.243369    23        7.091392  4408pylho1
# 50  4501ppvho1.mrxs   24.009896    95        3.956702  4501ppvho1
# 51  4502pglho1.mrxs   21.354834   100        4.682781  4502pglho1
# 52  4503ppvho1.mrxs   36.898215   216        5.853942  4503ppvho1
# 53  4503pylho1.mrxs    3.041875    26        8.547361  4503pylho1
# 54  4504pglho1.mrxs    9.537038    50        5.242718  4504pglho1
# 55  4507pylho1.mrxs    8.326973   181       21.736589  4507pylho1

# %%
#correlation of cellcount by manual and cellcount by AI on the full slide

portion_short = ['pp', 'pg', 'py']
portion =['ppv', 'pgl', 'pyl']

##collect all data in one dataframe
df_slide = df_musk.groupby(['short_image']).agg({'cell_count': ['mean', 'std']}).reset_index()
df_slide['animal'] = df_slide['short_image'].str[:2]
df_slide['genotype'] = df_slide['animal'].apply(lambda x: 'WT' if int(x) in [36,38,41,43,45] else 'TG')
df_slide['portion_short'] = df_slide['short_image'].str[5:7]
df_slide['portion'] = df_slide['portion_short'].apply(lambda x: portion[portion_short.index(x)])
df_slide.columns = ['slide', 'mean_cell_slide', 'std_cell_slide', 'animal','genotype','portion_short', 'portion']


df_slide['portion_3'] = df_slide['portion'].apply(lambda x: 'v' if 'pp' in x else 'l')

df_slide['ID'] = df_slide['slide'].str[:2]+'0'+ df_slide['slide'].str[3]+ df_slide['portion'] +stain
print(df_slide)

df_slide_compare = df_slide.merge(df_AI_fullslide, on = 'ID')

df_slide_compare = df_slide_compare.drop(columns =['slide_x', 'animal', 'genotype', 'portion', 'slide_y', 'portion_3'])



correlation_coefficient = df_slide_compare['mean_cell_slide'].corr(df_slide_compare['count per area'])
## calculate pearson rho
print("Pearson correlation coefficient:", correlation_coefficient)

##plot scatter plot with the correlation
plt.scatter(df_slide_compare['mean_cell_slide'] ,df_slide_compare['count per area'])
plt.xlim(0, 30,2)
plt.ylim(0,80)
plt.xlabel('Manuelle Auswertung \n[Zellen pro mpf]', fontsize = 12)
plt.ylabel('Auswertung mit AI \n[Zellen pro mm^2]', fontsize = 12)
plt.title(marker+': Korrelation von manueller Auswertung und AI auf WSI', fontsize = 14)

plt.text(20, 3, 'ρ = {:.2f}'.format(correlation_coefficient), fontsize=12)
plt.show()
# Out:
#        slide  mean_cell_slide  std_cell_slide animal genotype portion_short  \
# 0   36-4 py          5.772727        3.766163     36       WT            py
# 1   36-5 ppv         6.333333        5.816643     36       WT            pp
# 2   36-6 pgl         4.187500        4.888336     36       WT            pg
# 3   36-6 ppv         6.347826        4.867412     36       WT            pp
# 4   36-7 pgl         7.533333       10.301641     36       WT            pg
# 5   36-7 py          3.809524        4.749937     36       WT            py
# 6   37-1 py          1.156250        2.156900     37       TG            py
# 7   37-2 pgl         3.733333        5.324695     37       TG            pg
# 8   37-2 ppv         9.285714       11.424862     37       TG            pp
# 9   37-3 ppv        13.923077        8.479992     37       TG            pp
# 10  37-4 py          4.529412        7.378245     37       TG            py
# 11  37-8 pgl         7.050000       12.991799     37       TG            pg
# 12  38-2 pgl         7.000000        5.816643     38       WT            pg
# 13  38-2 ppv         1.700000        2.750757     38       WT            pp
# 14  38-3 pgl         4.896552        8.125554     38       WT            pg
# 15  38-6 py          0.909091        1.230915     38       WT            py
# 16  38-7 ppv         6.850000        4.749238     38       WT            pp
# 17  38-7 py         10.083333       10.175356     38       WT            py
# 18  39-2 pgl         2.933333        4.165619     39       TG            pg
# 19  39-2 py          3.461538        1.613246     39       TG            py
# 20  39-3 ppv         2.400000        3.476109     39       TG            pp
# 21  39-3 py          3.571429        2.439750     39       TG            py
# 22  39-7 pgl         2.461538        3.125577     39       TG            pg
# 23  40-2 ppv         3.562500        3.811714     40       TG            pp
# 24  40-4 ppv         9.409091        7.149153     40       TG            pp
# 25  40-4 py          3.000000        2.983287     40       TG            py
# 26  40-6 pgl         6.304348        4.939956     40       TG            pg
# 27  40-7 pgl         5.133333        5.514483     40       TG            pg
# 28  40-7 py          7.222222        5.449261     40       TG            py
# 29  41-2 pgl         2.916667        5.333570     41       WT            pg
# 30  41-2 ppv         2.095238        1.729299     41       WT            pp
# 31  41-2 py          4.423077        3.941300     41       WT            py
# 32  41-5 pgl         4.555556        3.649693     41       WT            pg
# 33  41-7 ppv         2.392857        2.131584     41       WT            pp
# 34  41-7 py          2.750000        3.356586     41       WT            py
# 35  42-2 pgl         3.027027        5.372184     42       TG            pg
# 36  42-2 ppv         7.041667        4.582378     42       TG            pp
# 37  42-2 py          2.960000        2.700000     42       TG            py
# 38  42-7 pgl         2.068966        2.463027     42       TG            pg
# 39  42-7 ppv         3.166667        2.622744     42       TG            pp
# 40  42-7 py          0.722222        0.894792     42       TG            py
# 41  43-2 pgl         5.400000        2.988868     43       WT            pg
# 42  43-2 ppv         5.454545        3.262007     43       WT            pp
# 43  43-2 py          1.380952        2.459191     43       WT            py
# 44  43-7 pgl         7.000000        4.546061     43       WT            pg
# 45  43-7 ppv         3.708333        4.206405     43       WT            pp
# 46  43-7 py          9.222222        8.996913     43       WT            py
# 47  44-2 pgl         4.545455        3.984059     44       TG            pg
# 48  44-2 ppv         3.800000        1.643168     44       TG            pp
# 49  44-4 ppv         1.470588        1.940285     44       TG            pp
# 50  44-6 py          2.181818        2.821992     44       TG            py
# 51  44-8 pgl         4.555556        2.727253     44       TG            pg
# 52  44-8 py          0.500000        0.836660     44       TG            py
# 53  45-1 ppv         1.500000        2.236068     45       WT            pp
# 54  45-2 pgl         2.000000        3.162278     45       WT            pg
# 55  45-3 ppv         2.541667        2.466809     45       WT            pp
# 56  45-3 py          1.000000        0.816497     45       WT            py
# 57  45-4 pgl         1.777778        2.048034     45       WT            pg
#
#    portion portion_3          ID
# 0      pyl         l  3604pylho1
# 1      ppv         v  3605ppvho1
# 2      pgl         l  3606pglho1
# 3      ppv         v  3606ppvho1
# 4      pgl         l  3607pglho1
# 5      pyl         l  3607pylho1
# 6      pyl         l  3701pylho1
# 7      pgl         l  3702pglho1
# 8      ppv         v  3702ppvho1
# 9      ppv         v  3703ppvho1
# 10     pyl         l  3704pylho1
# 11     pgl         l  3708pglho1
# 12     pgl         l  3802pglho1
# 13     ppv         v  3802ppvho1
# 14     pgl         l  3803pglho1
# 15     pyl         l  3806pylho1
# 16     ppv         v  3807ppvho1
# 17     pyl         l  3807pylho1
# 18     pgl         l  3902pglho1
# 19     pyl         l  3902pylho1
# 20     ppv         v  3903ppvho1
# 21     pyl         l  3903pylho1
# 22     pgl         l  3907pglho1
# 23     ppv         v  4002ppvho1
# 24     ppv         v  4004ppvho1
# 25     pyl         l  4004pylho1
# 26     pgl         l  4006pglho1
# 27     pgl         l  4007pglho1
# 28     pyl         l  4007pylho1
# 29     pgl         l  4102pglho1
# 30     ppv         v  4102ppvho1
# 31     pyl         l  4102pylho1
# 32     pgl         l  4105pglho1
# 33     ppv         v  4107ppvho1
# 34     pyl         l  4107pylho1
# 35     pgl         l  4202pglho1
# 36     ppv         v  4202ppvho1
# 37     pyl         l  4202pylho1
# 38     pgl         l  4207pglho1
# 39     ppv         v  4207ppvho1
# 40     pyl         l  4207pylho1
# 41     pgl         l  4302pglho1
# 42     ppv         v  4302ppvho1
# 43     pyl         l  4302pylho1
# 44     pgl         l  4307pglho1
# 45     ppv         v  4307ppvho1
# 46     pyl         l  4307pylho1
# 47     pgl         l  4402pglho1
# 48     ppv         v  4402ppvho1
# 49     ppv         v  4404ppvho1
# 50     pyl         l  4406pylho1
# 51     pgl         l  4408pglho1
# 52     pyl         l  4408pylho1
# 53     ppv         v  4501ppvho1
# 54     pgl         l  4502pglho1
# 55     ppv         v  4503ppvho1
# 56     pyl         l  4503pylho1
# 57     pgl         l  4504pglho1
# Pearson correlation coefficient: 0.7467172208570669
